# %%
import pydicom
from pathlib import Path
import matplotlib.pyplot as plt

# %%
FILE_PATH = '/home/demyanchuk/Projects/TMP/TCGA-GBM/TCGA-02-0003/06-08-1997-MRI BRAIN WWO CONTRAMR-81239/10-AX T2 FSE-23822/000023.dcm'

# %%
ds = pydicom.read_file(FILE_PATH)
data = ds.pixel_array
data.shape
# Out:
# (256, 256)

# %%
plt.imshow(data, cmap='gray')
